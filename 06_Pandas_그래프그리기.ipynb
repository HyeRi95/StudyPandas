# %% [markdown]
# # 그래프 그리기

# %% [markdown]
# scipy와 seaborn 충돌,
# cmd 켜서
# pip uninstall scipy /
# pip uninstall seaborn /
# pip install seaborn /
# 진행한 후에 import 진행

# %%
import seaborn as sns

# %% [markdown]
# > 앤스콤 데이터 불러오기

# %%
anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %%
anscombe.groupby('dataset').mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
anscombe.groupby('dataset').var()
# Out:
#             x         y
# dataset
# I        11.0  4.127269
# II       11.0  4.127629
# III      11.0  4.122620
# IV       11.0  4.123249

# %%
anscombe[anscombe['dataset'] =='I'].corr() # 1유형 상관계수
# Out:
#           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000

# %%
anscombe[anscombe['dataset'] =='II'].corr()
# Out:
#           x         y
# x  1.000000  0.816237
# y  0.816237  1.000000

# %%
anscombe[anscombe['dataset'] =='III'].corr()
# Out:
#           x         y
# x  1.000000  0.816287
# y  0.816287  1.000000

# %%
anscombe[anscombe['dataset'] =='IV'].corr()
# Out:
#           x         y
# x  1.000000  0.816521
# y  0.816521  1.000000

# %% [markdown]
# > 그래프 그리기 ( I번 데이터 )

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
dataset_1 = anscombe[anscombe['dataset']=='I']
plt.plot(dataset_1['x'], dataset_1['y'])
plt.show()

# %%
plt.plot(dataset_1['x'], dataset_1['y'],'o')

# %%
plt.plot(dataset_1['x'], dataset_1['y'],'r*') # matplotlib 마커 검색

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
fig = plt.figure() # 그래프 기본 틀 생성
axes1 = fig.add_subplot(2,2,1)    # row, col, index
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'ro')
axes2.plot(dataset_2['x'],dataset_2['y'],'go')
axes3.plot(dataset_3['x'],dataset_3['y'],'bo')
axes4.plot(dataset_4['x'],dataset_4['y'],'mo')
fig

# %%
fig.tight_layout() # 레이아웃 최적화 
fig

# %% [markdown]
# ## 기초 그래프 그리기

# %%
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# > 기초그래프 : 히스토그램

# %%
fig = plt.figure(figsize=(20,20))
fig =plt.figure()
axes1 = fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'], bins = 10 , color='salmon') # bins : 간격
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'], c='skyblue')
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot(
    [tips[tips['sex']=='Female']['tip'],
     tips[tips['sex']=='Male']['tip']],
    labels = ['Female','Male'])

axes1.set_xlabel('Gender')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Gender')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Gender')

# %% [markdown]
# > 다변량 그래프 그리기

# %%
def recode_gender(gender):
    if gender == 'Female':
        return 'red'
    else:
        return 'blue'

# %%
tips['color'] = tips['sex'].apply(recode_gender)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size color
# 0       16.99  1.01  Female     No  Sun  Dinner     2   red
# 1       10.34  1.66    Male     No  Sun  Dinner     3  blue
# 2       21.01  3.50    Male     No  Sun  Dinner     3  blue
# 3       23.68  3.31    Male     No  Sun  Dinner     2  blue
# 4       24.59  3.61  Female     No  Sun  Dinner     4   red

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size'] * 10,
    c = tips['color'],
    alpha = 0.5)

axes1.set_title('Total Bill vs Tip Colored by Gender and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# > bar 그래프 : 카운트 비교할때 사용

# %%
bar_plot = plt.figure()
axes1 = bar_plot.add_subplot(1,1,1)
axes1.bar(tips['sex'],tips['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %% [markdown]
# > seaborn 라이브러리로 단변량 그래프 그리기

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density plot')
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density plot')

# %%
tips = sns.load_dataset('tips')
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],kde = False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density plot')

# %%
tips = sns.load_dataset('tips')
ax = plt.subplots()
ax = sns.histplot(tips['total_bill'])
ax.set_title('Total Bill Histogram')
# Out:
# Text(0.5, 1.0, 'Total Bill Histogram')

# %%
tips = sns.load_dataset('tips')
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist = False)
ax.set_title('Total Bill Density')
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Density')

# %% [markdown]
# > 이변량 그래프 그리기 : 산점도

# %%
ax = plt.subplots()
ax = sns.regplot(x = 'total_bill',y='tip',data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = sns.regplot(x='total_bill',y='tip',
                data = tips, fit_reg=False)

# %% [markdown]
# > 이변량 그래프 그리기 : 산점도와 히스토그램 한번에 표현

# %%
joint = sns.jointplot(x='total_bill', y = 'tip',data=tips)
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize =10, y =1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
joint = sns.jointplot(x= 'total_bill',y='tip',data=tips,kind = 'hex')
joint.set_axis_labels(xlabel='Total Bill', ylabel ='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize= 10 , y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
ax = plt.subplots()
ax = sns.kdeplot(x=tips['total_bill'], y =tips['tip'], shade = True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# > 이변량 그래프 그리기 : 박스 그래프 표현

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time',y='total_bill',data=tips)
ax.set_title('Bosplot of total bill by time of day')
ax . set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('violin of total bill by time of day')
ax . set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# > 이변량 그래프 그리기 : 관계 그래프 표현

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\82102\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > 다변량 그래프 그리기 : 색상 추가로 표현

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y = 'total_bill',hue='sex' , data=tips, split=True)

# %%
scatter = sns.lmplot(x='total_bill', y='tip',data=tips, hue='sex', fit_reg=False)

# %%
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# > 다변량 그래프 그리기 : 크기와 모양으로 표현

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg=False, scatter_kws={'s':tips['size']*10})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg = False, hue='sex',markers=['o','x'])

# %%
# 그래프그릴때 한글제목 범례 적용 시키기
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NanumGothicCoding.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font' , family=font)

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('Violinplot of total bill by time of day')
ax . set_xlabel('식사시간')
ax.set_ylabel('총금액')
# Out:
# Text(0, 0.5, '총금액')

# %% [markdown]
# ## 데이터 프레임과 시리즈로 그래프 그리기

# %%
tips.plot()
# Out:
# <AxesSubplot:>

# %%
tips['total_bill'].plot()
# Out:
# <AxesSubplot:>

# %%
tips[['total_bill', 'tip']].plot()
# Out:
# <AxesSubplot:>

# %%
tips[['size','total_bill']].plot(x='size',y='total_bill', c='red')
# Out:
# <AxesSubplot:xlabel='size'>

# %% [markdown]
# > 데이터 프레임 또는 시리즈의 plpt 속성에 정이된 여러메소드 사용

# %%
tips['total_bill'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips.plot.scatter(x='total_bill', y = 'tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.plot.box()
# Out:
# <AxesSubplot:>

# %%
tips.plot.hexbin(x='total_bill',y='tip',gridsize=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
