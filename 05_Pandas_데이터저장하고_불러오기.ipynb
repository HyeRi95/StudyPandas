# %% [markdown]
# ## pickle

# %% [markdown]
# 데이터를 바이너리 형태로 직렬화 하여 저장, 적은용량으로 저장가능

# %%
import pandas as pd
scientists = pd.read_csv('C:/STUDY/StudyPandas/data/scientists.csv')
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
names = scientists['Name']

# %%
names.to_pickle('C:/STUDY/StudyPandas/data/scientists_names_series.pickle')

# %%
scientists.to_pickle('C:/STUDY/StudyPandas/data/scientists_df.pickle')

# %%
pd.read_pickle('C:/STUDY/StudyPandas/data/scientists_df.pickle')
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
scientists['Name'].to_csv('scientist_names_series.csv')

# %%
scientists.to_csv('C:/STUDY/StudyPandas/data/scientists.csv')

# %%
df = pd.read_csv('C:/STUDY/StudyPandas/data/scientists.csv',index_col=0)

# %%
df
# Out:
#                             Born        Died  Age          Occupation
# Name
# Rosaline Franklin     1920-07-25  1958-04-16   37             Chemist
# William Gosset        1876-06-13  1937-10-16   61        Statistician
# Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# Marie Curie           1867-11-07  1934-07-04   66             Chemist
# Rachel Carson         1907-05-27  1964-04-14   56           Biologist
# John Snow             1813-03-15  1858-06-16   45           Physician
# Alan Turing           1912-06-23  1954-06-07   41  Computer Scientist
# Johann Gauss          1777-04-30  1855-02-23   77       Mathematician

# %%
df = pd.read_csv('C:/STUDY/StudyPandas/data/scientists.csv',index_col=0)

# %% [markdown]
# # EXCEL

# %% [markdown]
# excel 저장하기

# %%
# 라이브러리 설치 왜 안되지??? 
# !conda install -y xlwt
# !conda install -y openpyxl
# Out:
# ...
# WARNING conda.exceptions:print_unexpected_error_report(1216): KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "C:\Users\82102\anaconda3\lib\site-packages\conda\exceptions.py", line 1082, in __call__
#     return func(*args, **kwargs)
#   File "C:\Users\82102\anaconda3\lib\site-packages\conda\cli\main.py", line 87, in _main
#     exit_code = do_call(args, p)
#   File "C:\Users\82102\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 84, in do_call
#     return getattr(module, func_name)(args, parser)
#   File "C:\Users\82102\anaconda3\lib\site-packages\conda\cli\main_install.py", line 20, in execute
#     install(args, parser, 'install')
#   File "C:\Users\82102\anaconda3\lib\site-packages\conda\cli\install.py", line 260, in install
#     unlink_link_transaction = solver.solve_for_transaction(
#   File "C:\Users\82102\anaconda3\lib\site-packages\conda\core\solve.py", line 152, in solve_for_transaction
# ...

# %%
names_df = scientists[['Name']]
import xlwt
import openpyxl

# %%
names_df.to_excel('C:/STUDY/StudyPandas/data/scientists_names_series_df.xls')
names_df.to_excel('C:/STUDY/StudyPandas/data/scientists_names_series_df.xlsx')
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_1664\2297412835.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   names_df.to_excel('C:/STUDY/StudyPandas/data/scientists_names_series_df.xls')
